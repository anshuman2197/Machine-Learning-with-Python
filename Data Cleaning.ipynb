# %% [markdown]
# # Standarisation

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('C://Users//Mypc//Desktop//Goeduhub Technology//IMDB-Movie-Data.csv')
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df.columns=df.columns.str.strip().str.upper().str.replace('_','')
df.head()
# Out:
#    RANK                    TITLE                     GENRE  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          DESCRIPTION              DIRECTOR  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               ACTORS  YEAR  RUNTIME (MINUTES)  \
# ...

# %%
df.columns=df.columns.str.strip().str.lower().str.replace('_','')
df
# Out:
#      rank                    title                     genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            description              director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.head()
# Out:
#    rank                    title                     genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          description              director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               actors  year  runtime (minutes)  \
# ...

# %%
df['director']=df['director'].str.upper()
df
# Out:
#      rank                    title                     genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            description              director  \
# 0    A group of intergalactic criminals are forced ...            JAMES GUNN
# ...

# %%
df['runtime(minutes)']=df['runtime(minutes)']*60
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'runtime(minutes)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-68bc81d2c4ad> in <module>
# ...

# %%
df.dtypes
# Out:
# rank                    int64
# title                  object
# genre                  object
# description            object
# director               object
# actors                 object
# year                    int64
# runtime (minutes)       int64
# rating                float64
# votes                   int64
# revenue (millions)    float64
# metascore             float64
# dtype: object

# %%
df['rating']=df['rating'].apply(np.int64)
df
# Out:
#      rank                    title                     genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            description              director  \
# 0    A group of intergalactic criminals are forced ...            JAMES GUNN
# ...

# %%
df.dtypes
# Out:
# rank                    int64
# title                  object
# genre                  object
# description            object
# director               object
# actors                 object
# year                    int64
# runtime (minutes)       int64
# rating                  int64
# votes                   int64
# revenue (millions)    float64
# metascore             float64
# dtype: object

# %%
df.head()
# Out:
#    rank                    title                     genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          description              director  \
# 0  A group of intergalactic criminals are forced ...            JAMES GUNN
# 1  Following clues to the origin of mankind, a te...          RIDLEY SCOTT
# 2  Three girls are kidnapped by a man with a diag...    M. NIGHT SHYAMALAN
# 3  In a city of humanoid animals, a hustling thea...  CHRISTOPHE LOURDELET
# 4  A secret government agency recruits some of th...            DAVID AYER
#
#                                               actors  year  runtime (minutes)  \
# ...

# %% [markdown]
# # Syntax Error

# %%
df['director']=df['director'].str.replace('DAVID AYER','DAVID EYER')
df.head()
# Out:
#    rank                    title                     genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          description              director  \
# 0  A group of intergalactic criminals are forced ...            JAMES GUNN
# 1  Following clues to the origin of mankind, a te...          RIDLEY SCOTT
# 2  Three girls are kidnapped by a man with a diag...    M. NIGHT SHYAMALAN
# 3  In a city of humanoid animals, a hustling thea...  CHRISTOPHE LOURDELET
# 4  A secret government agency recruits some of th...            DAVID EYER
#
#                                               actors  year  runtime (minutes)  \
# ...

# %%
df['title']=df['title'].str.strip()

# %%
df['title']
# Out:
# 0      Guardians of the Galaxy
# 1                   Prometheus
# 2                        Split
# 3                         Sing
# 4                Suicide Squad
#                 ...
# 995       Secret in Their Eyes
# 996            Hostel: Part II
# 997     Step Up 2: The Streets
# 998               Search Party
# 999                 Nine Lives
# Name: title, Length: 1000, dtype: object

# %%
df['description']
# Out:
# 0      A group of intergalactic criminals are forced ...
# 1      Following clues to the origin of mankind, a te...
# 2      Three girls are kidnapped by a man with a diag...
# 3      In a city of humanoid animals, a hustling thea...
# 4      A secret government agency recruits some of th...
#                              ...
# 995    A tight-knit team of rising investigators, alo...
# 996    Three American college students studying abroa...
# 997    Romantic sparks occur between two dance studen...
# 998    A pair of friends embark on a mission to reuni...
# 999    A stuffy businessman finds himself trapped ins...
# Name: description, Length: 1000, dtype: object

# %%
df.dropna(how='all',inplace=True)

# %%
df
# Out:
#      rank                    title                     genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            description              director  \
# 0    A group of intergalactic criminals are forced ...            JAMES GUNN
# ...

# %%
df['title']=df['title'].str.pad(1,side='right',fillchar='_')

# %%
df
# Out:
#      rank                    title                     genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2             Prometheus__  Adventure,Mystery,Sci-Fi
# 2       3             Split_______           Horror,Thriller
# 3       4             Sing________   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000             Nine Lives__     Comedy,Family,Fantasy
#
#                                            description              director  \
# 0    A group of intergalactic criminals are forced ...            JAMES GUNN
# ...

# %% [markdown]
# # Irrelevant Data

# %%
# prerequisites
df1=pd.read_csv('C://Users//Mypc//Desktop//Goeduhub Technology//IMDB-Movie-Data.csv')

# %%
df1
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df1.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df1.shape
# Out:
# (1000, 12)

# %%
df1.drop(['Genre'],axis=1,inplace=True)
df1
# Out:
#      Rank                                        Description  \
# 0       1  A group of intergalactic criminals are forced ...
# 1       2  Following clues to the origin of mankind, a te...
# 2       3  Three girls are kidnapped by a man with a diag...
# 3       4  In a city of humanoid animals, a hustling thea...
# 4       5  A secret government agency recruits some of th...
# ..    ...                                                ...
# 995   996  A tight-knit team of rising investigators, alo...
# 996   997  Three American college students studying abroa...
# 997   998  Romantic sparks occur between two dance studen...
# 998   999  A pair of friends embark on a mission to reuni...
# 999  1000  A stuffy businessman finds himself trapped ins...
#
#                  Director                                             Actors  \
# 0              James Gunn  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# ...

# %%
df.head()
# Out:
#    rank                                        description  \
# 0     1  A group of intergalactic criminals are forced ...
# 1     2  Following clues to the origin of mankind, a te...
# 2     3  Three girls are kidnapped by a man with a diag...
# 3     4  In a city of humanoid animals, a hustling thea...
# 4     5  A secret government agency recruits some of th...
#
#                director                                             actors  \
# 0            JAMES GUNN  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# 1          RIDLEY SCOTT  Noomi Rapace, Logan Marshall-Green, Michael Fa...
# 2    M. NIGHT SHYAMALAN  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# 3  CHRISTOPHE LOURDELET  Matthew McConaughey,Reese Witherspoon, Seth Ma...
# 4            DAVID EYER  Will Smith, Jared Leto, Margot Robbie, Viola D...
#
#    year  runtime (minutes)  rating   votes  revenue (millions)  metascore
# 0  2014                121       8  757074              333.13       76.0
# ...

# %%
df['votes']=np.where(df['votes']==df['metascore'],'True','False')
df.head()
# Out:
#    rank                                        description  \
# 0     1  A group of intergalactic criminals are forced ...
# 1     2  Following clues to the origin of mankind, a te...
# 2     3  Three girls are kidnapped by a man with a diag...
# 3     4  In a city of humanoid animals, a hustling thea...
# 4     5  A secret government agency recruits some of th...
#
#                director                                             actors  \
# 0            JAMES GUNN  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# 1          RIDLEY SCOTT  Noomi Rapace, Logan Marshall-Green, Michael Fa...
# 2    M. NIGHT SHYAMALAN  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# 3  CHRISTOPHE LOURDELET  Matthew McConaughey,Reese Witherspoon, Seth Ma...
# 4            DAVID EYER  Will Smith, Jared Leto, Margot Robbie, Viola D...
#
#    year  runtime (minutes)  rating  votes  revenue (millions)  metascore
# 0  2014                121       8  False              333.13       76.0
# ...

# %%
df.loc[df['votes']=='True']
df
# Out:
#      rank                                        description  \
# 0       1  A group of intergalactic criminals are forced ...
# 1       2  Following clues to the origin of mankind, a te...
# 2       3  Three girls are kidnapped by a man with a diag...
# 3       4  In a city of humanoid animals, a hustling thea...
# 4       5  A secret government agency recruits some of th...
# ..    ...                                                ...
# 995   996  A tight-knit team of rising investigators, alo...
# 996   997  Three American college students studying abroa...
# 997   998  Romantic sparks occur between two dance studen...
# 998   999  A pair of friends embark on a mission to reuni...
# 999  1000  A stuffy businessman finds himself trapped ins...
#
#                  director                                             actors  \
# 0              JAMES GUNN  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# ...

# %%
len(df.loc[df['votes']=='False'])
# Out:
# 1000

# %% [markdown]
# # Duplicates

# %%
import pandas as pd

# %%
df2=pd.read_csv('C://Users//Mypc//Desktop//Goeduhub Technology//IMDB-Movie-Data.csv')
df2
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df2.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df2.shape
# Out:
# (1000, 12)

# %%
df2[df2.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Rank, Title, Genre, Description, Director, Actors, Year, Runtime (Minutes), Rating, Votes, Revenue (Millions), Metascore]
# Index: []

# %%
sum(df2.duplicated())
# Out:
# 0

# %%
df_duplicates=df2.drop_duplicates()

# %%
df_duplicates
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df2.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df2.shape
# Out:
# (1000, 12)

# %%
duplicates_df=df2[df2.duplicated(['Votes'])]
duplicates_df
# Out:
#      Rank                Title                 Genre  \
# 505   506  City of Tiny Lights  Crime,Drama,Thriller
# 825   826           Crawlspace       Horror,Thriller
# 960   961               Trance   Crime,Drama,Mystery
#
#                                            Description      Director  \
# 505  In the teeming, multicultural metropolis of mo...   Pete Travis
# 825  A thriller centered around a widower who moves...  Phil Claydon
# 960  An art auctioneer who has become mixed up with...   Danny Boyle
#
#                                                 Actors  Year  \
# 505   Riz Ahmed, Billie Piper, James Floyd, Cush Jumbo  2016
# 825  Michael Vartan, Erin Moriarty, Nadine Velazque...  2016
# 960  James McAvoy, Rosario Dawson, Vincent Cassel,D...  2013
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 505                110     5.7    291                 NaN       54.0
# 825                 88     5.3   1427                 NaN       25.0
# ...

# %%
unique_df2=df2.drop_duplicates(['Votes'])
unique_df2
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
unique_df2.shape
# Out:
# (997, 12)

# %% [markdown]
# # Missing Data

# %%
# prerequisites
df3=pd.read_csv('C://Users//Mypc//Desktop//Goeduhub Technology//IMDB-Movie-Data.csv')
df3.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df3.isnull()
# Out:
#       Rank  Title  Genre  Description  Director  Actors   Year  \
# 0    False  False  False        False     False   False  False
# 1    False  False  False        False     False   False  False
# 2    False  False  False        False     False   False  False
# 3    False  False  False        False     False   False  False
# 4    False  False  False        False     False   False  False
# ..     ...    ...    ...          ...       ...     ...    ...
# 995  False  False  False        False     False   False  False
# 996  False  False  False        False     False   False  False
# 997  False  False  False        False     False   False  False
# 998  False  False  False        False     False   False  False
# 999  False  False  False        False     False   False  False
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 0                False   False  False               False      False
# 1                False   False  False               False      False
# ...

# %%
df3.isnull().any()
# Out:
# Rank                  False
# Title                 False
# Genre                 False
# Description           False
# Director              False
# Actors                False
# Year                  False
# Runtime (Minutes)     False
# Rating                False
# Votes                 False
# Revenue (Millions)     True
# Metascore              True
# dtype: bool

# %%
df3.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
df3.isnull().values.any()
# Out:
# True

# %%
df3.isnull().sum().sum()
# Out:
# 192

# %%
df_cleaned=df3.dropna(how='all')
df_cleaned
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df_without_columns=df3.dropna(axis=1,how='all')
df_without_columns
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df3.dropna(thresh=5)
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df=df3.copy()
df5=df.fillna(0)
df5
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# # Outliers

# %%
import seaborn as sns

# %%
outliers=pd.read_csv('C://Users//Mypc//Desktop//Goeduhub Technology//IMDB-Movie-Data.csv')
outliers.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
outliers_2016=outliers[outliers['Year']==2016]
outliers_2016.head()
# Out:
#    Rank           Title                     Genre  \
# 2     3           Split           Horror,Thriller
# 3     4            Sing   Animation,Comedy,Family
# 4     5   Suicide Squad  Action,Adventure,Fantasy
# 5     6  The Great Wall  Action,Adventure,Fantasy
# 6     7      La La Land        Comedy,Drama,Music
#
#                                          Description              Director  \
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
# 5  European mercenaries searching for black powde...           Yimou Zhang
# 6  A jazz pianist falls for an aspiring actress i...       Damien Chazelle
#
#                                               Actors  Year  Runtime (Minutes)  \
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016                117
# ...

# %%
bplot=sns.boxplot(data=outliers_2016,width=0.5,palette='colorblind')
